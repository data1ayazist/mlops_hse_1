# %%
import yaml
import boto3
from botocore.exceptions import NoCredentialsError, PartialCredentialsError, ClientError

# Откройте и загрузите YAML-файл
with open('configs/config.yml') as config_file:
    config = yaml.safe_load(config_file)

# Извлеките данные для подключения
MINIO_ENDPOINT = config['MINIO_ENDPOINT']
ACCESS_KEY = config['MINIO_ACCESS_KEY']
SECRET_KEY = config['MINIO_SECRET_KEY']
BUCKET_NAME = config['MINIO_BUCKET_NAME']

print(f'Endpoint: {MINIO_ENDPOINT}')
print(f'Access Key: {ACCESS_KEY}')
print(f'Secret Key: {SECRET_KEY}')
print(f'Bucket Name: {BUCKET_NAME}')

# Создайте сессию с использованием MinIO
session = boto3.session.Session()
s3 = session.client('s3',
                    endpoint_url=f'http://{MINIO_ENDPOINT}',
                    aws_access_key_id=ACCESS_KEY,
                    aws_secret_access_key=SECRET_KEY)
# Out:
# Endpoint: localhost:9000
# Access Key: Gipsy_Kings
# Secret Key: Gipsy_Kings
# Bucket Name: mlops

# %%
s3

# %%
# Функция для создания бакета
def create_bucket(bucket_name):
    try:
        s3.create_bucket(Bucket=bucket_name)
        print(f'Bucket "{bucket_name}" created.')
    except ClientError as e:
        if e.response['Error']['Code'] == 'BucketAlreadyOwnedByYou':
            print(f'Bucket "{bucket_name}" already exists and is owned by you.')
        else:
            print(f'Error creating bucket: {e}')

# Функция для создания папки в S3
def create_folder(bucket_name, folder_name):
    try:
        s3.put_object(Bucket=bucket_name, Key=(folder_name + '/'))
        print(f'Folder "{folder_name}" created in bucket "{bucket_name}".')
    except (NoCredentialsError, PartialCredentialsError):
        print("Credentials not available.")
    except Exception as e:
        print(f"Error creating folder: {e}")

# Создайте бакет
create_bucket(BUCKET_NAME)

# Создайте папки "models" и "data"
create_folder(BUCKET_NAME, 'models')
create_folder(BUCKET_NAME, 'data')
# Out:
# Bucket "mlops" created.
# Folder "models" created in bucket "mlops".
# Folder "data" created in bucket "mlops".

# %%
def list_folders(bucket_name):
    try:
        # Use the list_objects_v2 method to list objects in the bucket
        response = s3.list_objects_v2(Bucket=bucket_name, Delimiter='/')
        
        # Check if 'CommonPrefixes' is in the response
        if 'CommonPrefixes' in response:
            print(f'Folders in bucket "{bucket_name}":')
            for prefix in response['CommonPrefixes']:
                print(f' - {prefix["Prefix"]}')
        else:
            print(f'No folders found in bucket "{bucket_name}".')
    except (NoCredentialsError, PartialCredentialsError):
        print("Credentials not available.")
    except Exception as e:
        print(f"Error listing folders: {e}")

# List folders in the specified bucket
list_folders(BUCKET_NAME)
# Out:
# Folders in bucket "mlops":
#  - data/
#  - models/

# %%
import joblib
model = joblib.load(r"C:\Users\asus\Desktop\ФТИАД_MLOps\hw_2\models\my_model_3.joblib")
# Out:
# c:\Users\asus\AppData\Local\pypoetry\Cache\virtualenvs\mlops-hw-1-MdYKgCNj-py3.11\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator SVC from version 1.5.2 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
from io import BytesIO
import joblib
bytes_container = BytesIO()
joblib.dump(model, bytes_container)

bytes_container.seek(0)
model = joblib.load(bytes_container)

# %%
model
# Out:
# SVC(C=0.1)

# %%
from s3_client import get_s3_client
with open(r"C:\Users\asus\Desktop\ФТИАД_MLOps\hw_2\configs\config.yml", "r") as file:
        config = yaml.safe_load(file)
s3_client = get_s3_client(config)
bucket_name = config["MINIO_BUCKET_NAME"]
models_dir = config["models_dir"]
model_name = 's3'
model_path = f'{models_dir}/{model_name}.joblib'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 9
#       7 model_name = 's3'
#       8 model_path = f'{models_dir}/{model_name}.joblib'
# ----> 9 s3_client.download_fileobj(bucket_name, model_path, 'temp.joblib')
#
# File c:\Users\asus\AppData\Local\pypoetry\Cache\virtualenvs\mlops-hw-1-MdYKgCNj-py3.11\Lib\site-packages\boto3\s3\inject.py:783, in download_fileobj(self, Bucket, Key, Fileobj, ExtraArgs, Callback, Config)
#     744 """Download an object from S3 to a file-like object.
#     745
#     746 The file-like object must be in binary mode.
#    (...)
#     780     download.
#     781 """
#     782 if not hasattr(Fileobj, 'write'):
# --> 783     raise ValueError('Fileobj must implement write')
#     785 subscribers = None
#     786 if Callback is not None:
#
# ValueError: Fileobj must implement write

# %%
s3_client.download_file(bucket_name, model_path, 'qw/s3.joblib')

# %%
import tempfile
with tempfile.NamedTemporaryFile(delete=False) as f_source:
    s3_client.download_fileobj(bucket_name, model_path, f_source)

# %%
f_source.name
# Out:
# 'C:\\Users\\asus\\AppData\\Local\\Temp\\tmpe83ug1uu'

# %%
model = joblib.load(f'{f_source.name}\s3.joblib')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 model = joblib.load(f'{f_source.name}\s3.joblib')
#
# File c:\Users\asus\AppData\Local\pypoetry\Cache\virtualenvs\mlops-hw-1-MdYKgCNj-py3.11\Lib\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# ...

# %%
with open(f_source.name,"r") as f:
    model = joblib.load(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 with open(f_source.name,"r") as f:
# ----> 2     model = joblib.load(f)
#
# File c:\Users\asus\AppData\Local\pypoetry\Cache\virtualenvs\mlops-hw-1-MdYKgCNj-py3.11\Lib\site-packages\joblib\numpy_pickle.py:647, in load(filename, mmap_mode)
#     645     fobj = filename
#     646     filename = getattr(fobj, 'name', '')
# --> 647     with _read_fileobject(fobj, filename, mmap_mode) as fobj:
#     648         obj = _unpickle(fobj)
#     649 else:
#
# File ~\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# ...

# %%
import datetime

# %%
model_type = 'asc'
f"{model_type}_{datetime.datetime.now()}"
# Out:
# 'asc_2024-12-22 03:04:05.873141'
